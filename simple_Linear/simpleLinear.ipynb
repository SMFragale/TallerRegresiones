# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('../diamonds.csv')
data = dataset.loc[:,['carat', 'price']]
data.head(10)
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335
# 5   0.24    336
# 6   0.24    336
# 7   0.26    337
# 8   0.22    337
# 9   0.23    338

# %%
data.plot(x='carat', y='price', style='o')
plt.xlabel('carat')
plt.ylabel('price')
plt.show()

# %%
X = pd.DataFrame(data['carat'])
Y = pd.DataFrame(data['price'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (43154, 1)
# (10789, 1)
# (43154, 1)
# (10789, 1)

# %%
from sklearn.linear_model import LinearRegression
regress = LinearRegression()
regress.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regress.predict(X_test)

# %%
plt.scatter(X_train, Y_train, color = 'red')
plt.plot(X_train, regress.predict(X_train), color = 'blue')
plt.title('Price vs Carat (Training set)')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(X_test, Y_test, color = 'red')
plt.plot(X_train, regress.predict(X_train), color = 'blue')
plt.title('Price vs Carat (Training set)')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()
