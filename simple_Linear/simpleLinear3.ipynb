# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('../datasets/diamonds.csv')
data = dataset.loc[:,['table', 'price']]
data.head(10)
# Out:
#    table  price
# 0   55.0    326
# 1   61.0    326
# 2   65.0    327
# 3   58.0    334
# 4   58.0    335
# 5   57.0    336
# 6   57.0    336
# 7   55.0    337
# 8   61.0    337
# 9   61.0    338

# %%
data.plot(x='table', y='price', style='o')
plt.xlabel('table')
plt.ylabel('price')
plt.show()

# %%
X = pd.DataFrame(data['table'])
Y = pd.DataFrame(data['price'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regress = LinearRegression()
regress.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regress.predict(X_test)

# %%
plt.scatter(X_train, Y_train, color = 'red')
plt.plot(X_train, regress.predict(X_train), color = 'blue')
plt.title('Price vs table (Training set)')
plt.xlabel('table')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(X_test, Y_test, color = 'red')
plt.plot(X_train, regress.predict(X_train), color = 'blue')
plt.title('Price vs table (Training set)')
plt.xlabel('table')
plt.ylabel('Price')
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(X, Y))
